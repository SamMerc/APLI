# %% [markdown]
# ## Please insert some parameters
# * the name of the source

# %%
source = 'Cen X-3'

# %% [markdown]
# ### Imports

# %%
import hratio
import numpy as np
from astropy.table import Table
# %matplotlib notebook
import matplotlib.pyplot as plt
from scipy.stats import norm
import shutil
import os, sys
from astroquery.simbad import Simbad
from astropy import units as u
from astropy.coordinates import SkyCoord
from importlib import reload
from astropy.io import fits as pf

# %% [markdown]
# ## Importing modules developed for this project:
# * nustarpipeline process to wrap the nustar analysis for our needs
# * nustarpipeline utils to collect useful functions
# * pyxmmsas (originally for XMM) for spectral fitting

# %%
from nustarpipeline import process, utils
import pyxmmsas as pysas

# %% [markdown]
# ## This is the spectral analysis.
# * First find a suitable model for your source, running xspec iteratively and save the model only, use the file as input mod_file below
# * the routine below provides a file files.xcm to start with a basic model called mod_base.xcm
# * compute the MCMC to get eror and corner plots
# * at a second iteration, you can just load the chain (comment and uncomment the lines starting with load_chain=...)
# * the chain commands are to create a script to be lunched externally and need to be tuned for the correct parameter number

# %% [markdown]
# ### load spectra and and a basic model in pyxspec

# %%
import xspec

#use the base model
mod_file = 'mod_base.xcm'

#The following is an attempt to plot the model without the cyclotron lines
#mod_file = 'mod_3gabs_zero.xcm'



outputfiles_basename = 'GW-%s-' % (mod_file.replace('../mod_', '').replace('.xcm',''))

#'bxa-run-model.xcm'
pn_spec="FPMA_sr_rbn.pi"
mos1_spec="FPMB_sr_rbn.pi"
mos2_spec="none"
ignore_string=['**-3.0,70.0-**']*2
print("Using output file basename " + outputfiles_basename)


load_chain=False
compute_errors=False
perform_fit=False
save_xcm=False
run_chain=False

chain_name, fit_res =pysas.epic_xspec_mcmc_fit(xspec, mod_file, 
                                outputfiles_basename = outputfiles_basename,
                                pn_spec = pn_spec,
                                mos1_spec = mos1_spec,
                                mos2_spec =mos2_spec, 
                                jeffreys_priors=['norm', 'nH', 'cutoffE', 'foldE'],
                                               #jeffreys_priors=['norm', 'nH', 'T0', 'kT', 'taup'],
                                ignore_string=ignore_string,
                                load_chain=load_chain, perform_fit=perform_fit, set_priors=True, walkers=60, 
                                               run_chain=run_chain,
                                               compute_errors=compute_errors, save_xcm=save_xcm )
# Out:
# Using output file basename GW-mod_base-
#    All chains are now removed.
#
# 2 spectra  in use
#
# Spectral Data File: FPMA_sr_rbn.pi  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  6.462e+01 +/- 5.501e-02 (99.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-2440
#   Telescope: NuSTAR Instrument: FPMA  Channel Type: PI
#   Exposure Time: 2.143e+04 sec
#  Using fit statistic: chi
#  Using Background File                FPMA_bk.pha
#   Background Exposure Time: 2.143e+04 sec
#  Using Response (RMF) File            FPMA_sr.rmf for Source 1
#  Using Auxiliary Response (ARF) File  FPMA_sr.arf
#
# Spectral Data File: FPMB_sr_rbn.pi  Spectrum 2
# Net count rate (cts/s) for Spectrum:2  6.067e+01 +/- 5.310e-02 (99.9 % total)
#  Assigned to Data Group 2 and Plot Group 2
#   Noticed Channels:  1-2442
#   Telescope: NuSTAR Instrument: FPMB  Channel Type: PI
#   Exposure Time: 2.158e+04 sec
#  Using fit statistic: chi
#  Using Background File                FPMB_bk.pha
#   Background Exposure Time: 2.158e+04 sec
#  Using Response (RMF) File            FPMB_sr.rmf for Source 1
#  Using Auxiliary Response (ARF) File  FPMB_sr.arf
#
# We load 2 spectra
# ignore:  2208 channels ignored from  source number 1
# ignore:  2208 channels ignored from  source number 2
#
# ['**-3.0,70.0-**', '**-3.0,70.0-**']
#     35 channels (1-35) ignored in spectrum #     1
#   2188 channels (253-2440) ignored in spectrum #     1
#
#     35 channels (1-35) ignored in spectrum #     2
#   2187 channels (256-2442) ignored in spectrum #     2
#
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996
# Parameter delta values for fits will now be 0.01 * parValue
#  Model systematic error set to 0
#
# ========================================================================
# Model TBabs<1>*highecut<2>*pegpwrlw<3> Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#                            Data group: 1
#    1    1   TBabs      nH         10^22    11.6872      +/-  0.0
#    2    2   highecut   cutoffE    keV      14.5868      +/-  0.0
#    3    2   highecut   foldE      keV      7.97188      +/-  0.0
#    4    3   pegpwrlw   PhoIndex            1.24744      +/-  0.0
#    5    3   pegpwrlw   eMin       keV      3.00000      frozen
#    6    3   pegpwrlw   eMax       keV      70.0000      frozen
#    7    3   pegpwrlw   norm                1.35073E+04  +/-  0.0
#                            Data group: 2
#    8    1   TBabs      nH         10^22    11.6872      = p1
#    9    2   highecut   cutoffE    keV      14.5868      = p2
#   10    2   highecut   foldE      keV      7.97188      = p3
#   11    3   pegpwrlw   PhoIndex            1.24744      = p4
#   12    3   pegpwrlw   eMin       keV      3.00000      frozen
#   13    3   pegpwrlw   eMax       keV      70.0000      frozen
#   14    3   pegpwrlw   norm                1.34221E+04  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                 3615.15     using 217 bins.
#                  Chi-Squared                 3359.48     using 220 bins.
# Total fit statistic                          6974.62     with 431 d.o.f.
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                 3615.15     using 217 bins.
#                  Chi-Squared                 3359.48     using 220 bins.
# Total fit statistic                          6974.62     with 431 d.o.f.
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: The file sent to Xset.restore(): mod_base.xcm
#     is not detected to be a file generated from Xset.save().
#     Xset.restore() usage is only intended for Xset.save() output.
#     General XSPEC/Tcl scripts may not fully execute in PyXspec.
#
#
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7195.14     with 431 d.o.f.
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7195.14     with 431 d.o.f.
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
# Resetting constants for fit
# jeffreys prior for TBabs nH
# jeffreys prior for highecut cutoffE
#
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7195.14     with 431 d.o.f.
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7204.98     with 431 d.o.f.
#    (Includes a Bayesian contribution of 4.92)
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7215.70     with 431 d.o.f.
#    (Includes a Bayesian contribution of 10.28)
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7224.00     with 431 d.o.f.
#    (Includes a Bayesian contribution of 14.43)
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
# jeffreys prior for highecut foldE
# uniform prior for pegpwrlw PhoIndex
# eMin  linked or frozen
# eMax  linked or frozen
# jeffreys prior for pegpwrlw norm
# nH  linked or frozen
# cutoffE  linked or frozen
# foldE  linked or frozen
# PhoIndex  linked or frozen
# eMin  linked or frozen
# eMax  linked or frozen
# jeffreys prior for pegpwrlw norm
# GW-mod_base-chain.fits
# Test statistics= 7247.602913462378 Chi2=
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7224.00     with 431 d.o.f.
#    (Includes a Bayesian contribution of 14.43)
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7262.04     with 431 d.o.f.
#    (Includes a Bayesian contribution of 33.45)
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                 3731.79     using 217 bins.
#                  C-Statistic                 3463.35     using 220 bins.
# Total fit statistic                          7300.06     with 431 d.o.f.
#    (Includes a Bayesian contribution of 52.46)
#
# Test statistic : Chi-Squared                 6974.62     using 437 bins.
#  Null hypothesis probability of 0.00e+00 with 431 degrees of freedom
#  Current data and model not fit yet.
# 6974.62230831555 dof= 431
# ***Warning: Fit is not current.
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
# PGPLOT /png: writing new file as GW-mod_base-euf_plot.png_2
# Fit Stat= 7247.602913462378 Chi2= 6974.62230831555 dof= 431
#
# Spectral parameters:
#
# 	nH__01 11.69 10^22 (0.00-0.00)
# 	cutoffE__02 14.59 keV (0.00-0.00)
# 	foldE__03 7.97 keV (0.00-0.00)
# 	PhoIndex__04 1.25  (0.00-0.00)
# 	eMin 3 keV
# 	eMax 70 keV
# 	norm__07 13507.30  (0.00-0.00)
# 	nH 12 10^22
# 	cutoffE 15 keV
# 	foldE 8 keV
# 	PhoIndex 1
# 	eMin 3 keV
# 	eMax 70 keV
# 	norm__14 13422.10  (0.00-0.00)

# %% [markdown]
# ## We make a fit with a more complex model

# %%
import xspec

run_chain = False
reload(pysas)
fit_by_bin={}

chains=[]
#mod_file=outputfiles_basename+'model.xcm'
#mod_file='../model_cut.xcm'
    
mod_file = 'mod_pcfabs_2gauss_2gabs.xcm'


outputfiles_basename = 'GW-%s-' % (mod_file.replace('../mod_', '').replace('.xcm',''))

#'bxa-run-model.xcm'
pn_spec="FPMA_sr_rbn.pi"
mos1_spec="FPMB_sr_rbn.pi"
mos2_spec="none"
ignore_string=['**-3.0,70.0-**']*2
print("Using output file basename " + outputfiles_basename)


if run_chain:
    load_chain=False
    compute_errors=True
    perform_fit=True
    save_xcm=True
else:
    load_chain=True
    compute_errors=True
    perform_fit=False
    save_xcm=False
    
    
chain_name, fit_res =pysas.epic_xspec_mcmc_fit(xspec, mod_file, 
                                outputfiles_basename = outputfiles_basename,
                                pn_spec = pn_spec,
                                mos1_spec = mos1_spec,
                                mos2_spec =mos2_spec, 
                                jeffreys_priors=['norm', 'nH', 'cutoffE', 'foldE'],
                                               #jeffreys_priors=['norm', 'nH', 'T0', 'kT', 'taup'],
                                ignore_string=ignore_string,
                                load_chain=load_chain, perform_fit=perform_fit, set_priors=True, walkers=60, 
                                               run_chain=run_chain,
                                               compute_errors=compute_errors, save_xcm=save_xcm, 
                                               burn=8000, runLength=64000, )
chains.append(chain_name)


chain_commands='''

chain clear
chain type gw
chain walkers 60
chain burn 26000
chain length 36000

bayes on
bayes 1 jeffreys
bayes 8 jeffreys
bayes 9 jeffreys
bayes 12 jeffreys
bayes 16 jeffreys
bayes 32 jeffreys
query yes
fit

chain proposal gaussian diagonal 1e-1 1e-5 0.2 0.5 0.1 10. 10.
chain run %schain.fits

quit
yes

'''%outputfiles_basename


exposure, tstart, tstop = pysas.get_spec_exp_times("FPMA_sr_rbn.pi")



#    break
# Out:
# Using output file basename GW-mod_pcfabs_2gauss_2gabs-
#    All chains are now removed.
#
# 2 spectra  in use
#
# Spectral Data File: FPMA_sr_rbn.pi  Spectrum 1
# Net count rate (cts/s) for Spectrum:1  6.462e+01 +/- 5.501e-02 (99.8 % total)
#  Assigned to Data Group 1 and Plot Group 1
#   Noticed Channels:  1-2440
#   Telescope: NuSTAR Instrument: FPMA  Channel Type: PI
#   Exposure Time: 2.143e+04 sec
#  Using fit statistic: chi
#  Using Background File                FPMA_bk.pha
#   Background Exposure Time: 2.143e+04 sec
#  Using Response (RMF) File            FPMA_sr.rmf for Source 1
#  Using Auxiliary Response (ARF) File  FPMA_sr.arf
#
# Spectral Data File: FPMB_sr_rbn.pi  Spectrum 2
# Net count rate (cts/s) for Spectrum:2  6.067e+01 +/- 5.310e-02 (99.9 % total)
#  Assigned to Data Group 2 and Plot Group 2
#   Noticed Channels:  1-2442
#   Telescope: NuSTAR Instrument: FPMB  Channel Type: PI
#   Exposure Time: 2.158e+04 sec
#  Using fit statistic: chi
#  Using Background File                FPMB_bk.pha
#   Background Exposure Time: 2.158e+04 sec
#  Using Response (RMF) File            FPMB_sr.rmf for Source 1
#  Using Auxiliary Response (ARF) File  FPMB_sr.arf
#
# We load 2 spectra
# ignore:  2208 channels ignored from  source number 1
# ignore:  2208 channels ignored from  source number 2
#
# ['**-3.0,70.0-**', '**-3.0,70.0-**']
#     35 channels (1-35) ignored in spectrum #     1
#   2188 channels (253-2440) ignored in spectrum #     1
#
#     35 channels (1-35) ignored in spectrum #     2
#   2187 channels (256-2442) ignored in spectrum #     2
#
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996
# Parameter delta values for fits will now be 0.01 * parValue
#  Model systematic error set to 0
#
# ========================================================================
# Model TBabs<1>*pcfabs<2>*gabs<3>*gabs<4>*highecut<5>(gaussian<6> + gaussian<7> + gaussian<8> + pegpwrlw<9>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#                            Data group: 1
#    1    1   TBabs      nH         10^22    2.51265      +/-  0.0
#    2    2   pcfabs     nH         10^22    39.1312      +/-  0.0
#    3    2   pcfabs     CvrFract            0.548171     +/-  0.0
#    4    3   gabs       LineE      keV      29.0658      +/-  0.0
#    5    3   gabs       Sigma      keV      4.53483      +/-  0.0
#    6    3   gabs       Strength            4.72753      +/-  0.0
#    7    4   gabs       LineE      keV      14.4982      +/-  0.0
#    8    4   gabs       Sigma      keV      0.679837     +/-  0.0
#    9    4   gabs       Strength            0.133931     +/-  0.0
#   10    5   highecut   cutoffE    keV      14.4219      +/-  0.0
#   11    5   highecut   foldE      keV      9.19382      +/-  0.0
#   12    6   gaussian   LineE      keV      6.35543      +/-  0.0
#   13    6   gaussian   Sigma      keV      0.186046     +/-  0.0
#   14    6   gaussian   norm                3.11788E-03  +/-  0.0
#   15    7   gaussian   LineE      keV      6.67000      frozen
#   16    7   gaussian   Sigma      keV      0.0          frozen
#   17    7   gaussian   norm                0.0          frozen
#   18    8   gaussian   LineE      keV      6.97000      frozen
#   19    8   gaussian   Sigma      keV      3.00000E-02  frozen
#   20    8   gaussian   norm                5.91873E-04  +/-  0.0
#   21    9   pegpwrlw   PhoIndex            1.31351      +/-  0.0
#   22    9   pegpwrlw   eMin       keV      3.00000      frozen
#   23    9   pegpwrlw   eMax       keV      70.0000      frozen
#   24    9   pegpwrlw   norm                1.37317E+04  +/-  0.0
#                            Data group: 2
#   25    1   TBabs      nH         10^22    2.51265      = p1
#   26    2   pcfabs     nH         10^22    39.1312      = p2
#   27    2   pcfabs     CvrFract            0.548171     = p3
#   28    3   gabs       LineE      keV      29.0658      = p4
#   29    3   gabs       Sigma      keV      4.53483      = p5
#   30    3   gabs       Strength            4.72753      = p6
#   31    4   gabs       LineE      keV      14.4982      = p7
#   32    4   gabs       Sigma      keV      0.679837     = p8
#   33    4   gabs       Strength            0.133931     = p9
#   34    5   highecut   cutoffE    keV      14.4219      = p10
#   35    5   highecut   foldE      keV      9.19382      = p11
#   36    6   gaussian   LineE      keV      6.35543      = p12
#   37    6   gaussian   Sigma      keV      0.186046     = p13
#   38    6   gaussian   norm                3.11788E-03  = p14
#   39    7   gaussian   LineE      keV      6.67000      = p15
#   40    7   gaussian   Sigma      keV      0.0          = p16
#   41    7   gaussian   norm                0.0          = p17
#   42    8   gaussian   LineE      keV      6.97000      = p18
#   43    8   gaussian   Sigma      keV      3.00000E-02  = p19
#   44    8   gaussian   norm                5.91873E-04  = p20
#   45    9   pegpwrlw   PhoIndex            1.31351      = p21
#   46    9   pegpwrlw   eMin       keV      3.00000      frozen
#   47    9   pegpwrlw   eMax       keV      70.0000      frozen
#   48    9   pegpwrlw   norm                1.36436E+04  +/-  0.0
# ________________________________________________________________________
#
#
# Fit statistic  : Chi-Squared                  253.32     using 217 bins.
#                  Chi-Squared                  242.95     using 220 bins.
# Total fit statistic                           496.27     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  496.27     using 437 bins.
#  Null hypothesis probability of 5.49e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : Chi-Squared                  253.32     using 217 bins.
#                  Chi-Squared                  242.95     using 220 bins.
# Total fit statistic                           496.27     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  496.27     using 437 bins.
#  Null hypothesis probability of 5.49e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# ***Warning: The file sent to Xset.restore(): mod_pcfabs_2gauss_2gabs.xcm
#     is not detected to be a file generated from Xset.save().
#     Xset.restore() usage is only intended for Xset.save() output.
#     General XSPEC/Tcl scripts may not fully execute in PyXspec.
#
#
# Default fit statistic is set to: C-Statistic
#    This will apply to all current and newly loaded spectra.
#
# Fit statistic  : C-Statistic                  253.87     using 217 bins.
#                  C-Statistic                  242.88     using 220 bins.
# Total fit statistic                           496.75     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  496.27     using 437 bins.
#  Null hypothesis probability of 5.49e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#
# Fit statistic  : C-Statistic                  253.87     using 217 bins.
#                  C-Statistic                  242.88     using 220 bins.
# Total fit statistic                           496.75     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  496.27     using 437 bins.
#  Null hypothesis probability of 5.49e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# Resetting constants for fit
# tbvabs Version 2.3
# Cosmic absorption with grains and H2, modified from
# Wilms, Allen, & McCray, 2000, ApJ 542, 914-924
# Questions: Joern Wilms
# joern.wilms@sternwarte.uni-erlangen.de
# joern.wilms@fau.de
#
# http://pulsar.sternwarte.uni-erlangen.de/wilms/research/tbabs/
#
# PLEASE NOTICE:
# To get the model described by the above paper
# you will also have to set the abundances:
#    abund wilm
#
# Note that this routine ignores the current cross section setting
# as it always HAS to use the Verner cross sections as a baseline.
#  WARNING - UnitsWarning: 'C-Statistic' did not parse as fits unit: Invalid character at col 1 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html
# WARNING: UnitsWarning: 'C-Statistic' did not parse as fits unit: Invalid character at col 1 If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# nH__1
# Fit statistic  : C-Statistic                  298.05     using 217 bins.
#                  C-Statistic                  251.11     using 220 bins.
# Total fit statistic                           549.16     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  550.42     using 437 bins.
#  Null hypothesis probability of 1.60e-05 with 419 degrees of freedom
#  Current data and model not fit yet.
#  2.28581057119521
# nH__2 38.46949151357822
#
# Fit statistic  : C-Statistic                  350.91     using 217 bins.
#                  C-Statistic                  286.49     using 220 bins.
# Total fit statistic                           637.40     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  640.65     using 437 bins.
#  Null hypothesis probability of 1.62e-11 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                  265.73     using 217 bins.
#                  C-Statistic                  243.47     using 220 bins.
# Total fit statistic                           509.21     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.61     using 437 bins.
#  Null hypothesis probability of 1.58e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# CvrFract__3 0.5564036015154674
# LineE__4 29.067889926200568
#
# Fit statistic  : C-Statistic                  265.75     using 217 bins.
#                  C-Statistic                  243.45     using 220 bins.
# Total fit statistic                           509.20     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.60     using 437 bins.
#  Null hypothesis probability of 1.58e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                  265.71     using 217 bins.
#                  C-Statistic                  243.50     using 220 bins.
# Total fit statistic                           509.21     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.61     using 437 bins.
#  Null hypothesis probability of 1.58e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# Sigma__5 4.534020076803425
# Strength__6 4.725832383193865
#
# Fit statistic  : C-Statistic                  265.68     using 217 bins.
#                  C-Statistic                  243.54     using 220 bins.
# Total fit statistic                           509.22     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.64     using 437 bins.
#  Null hypothesis probability of 1.58e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                  265.70     using 217 bins.
#                  C-Statistic                  243.54     using 220 bins.
# Total fit statistic                           509.23     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.66     using 437 bins.
#  Null hypothesis probability of 1.57e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# LineE__7 14.501569816171322
# Sigma__8 0.6775539560243323
#
# Fit statistic  : C-Statistic                  265.79     using 217 bins.
#                  C-Statistic                  243.45     using 220 bins.
# Total fit statistic                           509.24     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.67     using 437 bins.
#  Null hypothesis probability of 1.57e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                  265.74     using 217 bins.
#                  C-Statistic                  243.56     using 220 bins.
# Total fit statistic                           509.30     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.73     using 437 bins.
#  Null hypothesis probability of 1.56e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# Strength__9 0.13341981144635046
# cutoffE__10 14.424043042505954
#
# Fit statistic  : C-Statistic                  265.47     using 217 bins.
#                  C-Statistic                  243.93     using 220 bins.
# Total fit statistic                           509.40     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.94     using 437 bins.
#  Null hypothesis probability of 1.53e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                  265.98     using 217 bins.
#                  C-Statistic                  243.36     using 220 bins.
# Total fit statistic                           509.34     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.41     using 437 bins.
#  Null hypothesis probability of 1.61e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# foldE__11 9.18971593729127
# LineE__12 6.355654486089692
#
# Fit statistic  : C-Statistic                  265.87     using 217 bins.
#                  C-Statistic                  243.47     using 220 bins.
# Total fit statistic                           509.34     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.41     using 437 bins.
#  Null hypothesis probability of 1.61e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                  266.05     using 217 bins.
#                  C-Statistic                  243.31     using 220 bins.
# Total fit statistic                           509.36     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.42     using 437 bins.
#  Null hypothesis probability of 1.61e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# Sigma__13 0.1870144736854949
# norm__14 0.003136833766670226
#
# Fit statistic  : C-Statistic                  266.14     using 217 bins.
#                  C-Statistic                  243.51     using 220 bins.
# Total fit statistic                           509.65     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.73     using 437 bins.
#  Null hypothesis probability of 1.56e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                  266.08     using 217 bins.
#                  C-Statistic                  243.40     using 220 bins.
# Total fit statistic                           509.48     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  509.55     using 437 bins.
#  Null hypothesis probability of 1.59e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# norm__20 0.0005868779841847935
# PhoIndex__21 1.3112552921345921
#
# Fit statistic  : C-Statistic                  253.99     using 217 bins.
#                  C-Statistic                  243.09     using 220 bins.
# Total fit statistic                           497.09     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  496.38     using 437 bins.
#  Null hypothesis probability of 5.43e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#
# Fit statistic  : C-Statistic                  253.88     using 217 bins.
#                  C-Statistic                  243.09     using 220 bins.
# Total fit statistic                           496.97     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  496.40     using 437 bins.
#  Null hypothesis probability of 5.43e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
# norm__24 13735.789664528638
# norm__48 13648.281948892803
#
# Fit statistic  : C-Statistic                  253.88     using 217 bins.
#                  C-Statistic                  242.99     using 220 bins.
# Total fit statistic                           496.86     with 419 d.o.f.
#
# Test statistic : Chi-Squared                  496.41     using 437 bins.
#  Null hypothesis probability of 5.42e-03 with 419 degrees of freedom
#  Current data and model not fit yet.
#   New chain GW-mod_pcfabs_2gauss_2gabs-chain.fits is now loaded.
#   Default chain length is now set to length of GW-mod_pcfabs_2gauss_2gabs-chain.fits: 63960
#   Default walkers length is now set to: 60
# Test statistics= 496.86485592032784 Chi2= 496.41402699059944 dof= 419
#
# Parameters defined:
# ========================================================================
# Model TBabs<1>*pcfabs<2>*gabs<3>*gabs<4>*highecut<5>(gaussian<6> + gaussian<7> + gaussian<8> + pegpwrlw<9>) Source No.: 1   Active/On
# Model Model Component  Parameter  Unit     Value
#  par  comp
#                            Data group: 1
#    1    1   TBabs      nH         10^22    2.28605      +/-  0.0
#    2    2   pcfabs     nH         10^22    38.4715      +/-  0.0
#    3    2   pcfabs     CvrFract            0.556413     +/-  0.0
#    4    3   gabs       LineE      keV      29.0652      +/-  0.0
#    5    3   gabs       Sigma      keV      4.53339      +/-  0.0
#    6    3   gabs       Strength            4.72607      +/-  0.0
#    7    4   gabs       LineE      keV      14.5008      +/-  0.0
#    8    4   gabs       Sigma      keV      0.677685     +/-  0.0
#    9    4   gabs       Strength            0.133464     +/-  0.0
#   10    5   highecut   cutoffE    keV      14.4241      +/-  0.0
#   11    5   highecut   foldE      keV      9.18860      +/-  0.0
#   12    6   gaussian   LineE      keV      6.35608      +/-  0.0
#   13    6   gaussian   Sigma      keV      0.187000     +/-  0.0
#   14    6   gaussian   norm                3.12465E-03  +/-  0.0
#   15    7   gaussian   LineE      keV      6.67000      frozen
#   16    7   gaussian   Sigma      keV      0.0          frozen
#   17    7   gaussian   norm                0.0          frozen
#   18    8   gaussian   LineE      keV      6.97000      frozen
#   19    8   gaussian   Sigma      keV      3.00000E-02  frozen
#   20    8   gaussian   norm                5.88228E-04  +/-  0.0
#   21    9   pegpwrlw   PhoIndex            1.31135      +/-  0.0
#   22    9   pegpwrlw   eMin       keV      3.00000      frozen
#   23    9   pegpwrlw   eMax       keV      70.0000      frozen
#   24    9   pegpwrlw   norm                1.37358E+04  +/-  0.0
#                            Data group: 2
#   25    1   TBabs      nH         10^22    2.28605      = p1
#   26    2   pcfabs     nH         10^22    38.4715      = p2
#   27    2   pcfabs     CvrFract            0.556413     = p3
#   28    3   gabs       LineE      keV      29.0652      = p4
#   29    3   gabs       Sigma      keV      4.53339      = p5
#   30    3   gabs       Strength            4.72607      = p6
#   31    4   gabs       LineE      keV      14.5008      = p7
#   32    4   gabs       Sigma      keV      0.677685     = p8
#   33    4   gabs       Strength            0.133464     = p9
#   34    5   highecut   cutoffE    keV      14.4241      = p10
#   35    5   highecut   foldE      keV      9.18860      = p11
#   36    6   gaussian   LineE      keV      6.35608      = p12
#   37    6   gaussian   Sigma      keV      0.187000     = p13
#   38    6   gaussian   norm                3.12465E-03  = p14
#   39    7   gaussian   LineE      keV      6.67000      = p15
#   40    7   gaussian   Sigma      keV      0.0          = p16
#   41    7   gaussian   norm                0.0          = p17
#   42    8   gaussian   LineE      keV      6.97000      = p18
#   43    8   gaussian   Sigma      keV      3.00000E-02  = p19
#   44    8   gaussian   norm                5.88228E-04  = p20
#   45    9   pegpwrlw   PhoIndex            1.31135      = p21
#   46    9   pegpwrlw   eMin       keV      3.00000      frozen
#   47    9   pegpwrlw   eMax       keV      70.0000      frozen
#   48    9   pegpwrlw   norm                1.36477E+04  +/-  0.0
# ________________________________________________________________________
#
# ***Warning: Fit is not current.
# PGPLOT /png: writing new file as GW-mod_pcfabs_2gauss_2gabs-euf_plot.png_2
# *** Parameter 15 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 16 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 17 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 18 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 19 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 22 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 23 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 25 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 26 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 27 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 28 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 29 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 30 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 31 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 32 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 33 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 34 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 35 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 36 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 37 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 38 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 39 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 40 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 41 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 42 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 43 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 44 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 45 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 46 is not a variable model parameter and no confidence range will be calculated.
# *** Parameter 47 is not a variable model parameter and no confidence range will be calculated.
# Errors calculated from chains
#  Parameter   Credible Interval (68.27%)
#      1      2.28281      2.28921
#      2      38.4538      38.4911
#      3     0.556166     0.556685
#      4      29.0551      29.0754
#      5       4.5299      4.53663
#      6       4.7252      4.72686
#      7      14.4848      14.5161
#      8     0.676112     0.679216
#      9     0.133168     0.133772
#     10      14.4176        14.43
#     11        9.175      9.20122
#     12      6.35227      6.35964
#     13     0.186304     0.187682
#     14   0.00292286   0.00332392
#     20    0.0005603   0.00061576
#     21      1.30996      1.31288
#     24      13735.5      13736.2
#     48      13646.4      13649.1
# Fit Stat= 496.86485592032784 Chi2= 496.41402699059944 dof= 419
#
# Spectral parameters:
#
# 	nH__01 2 10^22 (2-2)
# 	nH__02 38 10^22 (38-38)
# 	CvrFract__03 0.6  (0.6-0.6)
# 	LineE__04 29 keV (29-29)
# 	Sigma__05 5 keV (5-5)
# 	Strength__06 5  (5-5)
# 	LineE__07 15 keV (14-15)
# 	Sigma__08 0.7 keV (0.7-0.7)
# 	Strength__09 0.13  (0.13-0.13)
# 	cutoffE__10 14 keV (14-14)
# 	foldE__11 9 keV (9-9)
# 	LineE__12 6 keV (6-6)
# 	Sigma__13 0.19 keV (0.19-0.19)
# 	norm__14 3e-03  (3e-03-3e-03)
# 	LineE 7 keV
# 	Sigma 0.00 keV
# 	norm 0.00
# 	LineE 7 keV
# 	Sigma 0.03 keV
# 	norm__20 6e-04  (6e-04-6e-04)
# 	PhoIndex__21 1  (1-1)
# 	eMin 3 keV
# 	eMax 70 keV
# 	norm__24 1.4e+04  (1.4e+04-1.4e+04)
# 	nH 2 10^22
# 	nH 38 10^22
# 	CvrFract 0.6
# 	LineE 29 keV
# 	Sigma 5 keV
# 	Strength 5
# 	LineE 15 keV
# 	Sigma 0.7 keV
# 	Strength 0.13
# 	cutoffE 14 keV
# 	foldE 9 keV
# 	LineE 6 keV
# 	Sigma 0.19 keV
# 	norm 3e-03
# 	LineE 7 keV
# 	Sigma 0.00 keV
# 	norm 0.00
# 	LineE 7 keV
# 	Sigma 0.03 keV
# 	norm 6e-04
# 	PhoIndex 1
# 	eMin 3 keV
# 	eMax 70 keV
# 	norm__48 1.4e+04  (1.4e+04-1.4e+04)

# %% [markdown]
# ## This estimated the goodness of fit (it is long)

# %%
if False:
   
    sorted_sampled_fit_statistics, best_fit_statistic, goodness = \
    pysas.goodness_from_chain(xspec, outputfiles_basename, n_sample=1000,
                            pn_spec=pn_spec,
                            mos1_spec=mos1_spec,
                            mos2_spec=mos2_spec,
                            ignore_string=ignore_string)
    ff=open(outputfiles_basename+'simul_test.txt','w')
    for x in sorted_sampled_fit_statistics:
        ff.write("%f\n" % x)
    ff.write("%f*\n" % best_fit_statistic)
    ff.close()
    os.chdir('..')
    plt.figure()
    plt.hist(sorted_sampled_fit_statistics, bins=20, label='Sample')
    plt.axvline(best_fit_statistic, color='red', label='Best fit')
    plt.xlabel('Test statistics')
    plt.ylabel('Simulations')
    plt.legend()

# %% [markdown]
# ## Please edit the next cell to display parameters of your model

# %%
import pyxmmsas as pysas
latex_label_dict=pysas.default_latex_label_dict.copy()
latex_label_dict.update({ 
                        'nH__01': '$N_\\mathrm{H}$',
                        'nH__1': '$N_\\mathrm{H}$',                        
    'rate' : 'Cts/s',
    'cstat': '$\chi^2_\\mathrm{red}$/d.o.f.',
    
    'LineE__15': '$E_\\mathrm{Fe}$',
    'Sigma__16': '$\sigma_\\mathrm{Fe}$',
    'norm__17': '$N_\\mathrm{Fe}$',
    
    'LineE__2' : '$E_\\mathrm{Cyc1}$',
    'LineE__02' : '$E_\\mathrm{Cyc1}$',
    'Sigma__3' : '$\sigma_\\mathrm{Cyc1}$',
    'Sigma__03' : '$\sigma_\\mathrm{Cyc1}$',
    'Strength__4' : '$\\tau_\\mathrm{Cyc1}$',
    'Strength__04' : '$\\tau_\\mathrm{Cyc1}$',
    
    'LineE__5' : '$E_\\mathrm{Cyc2}$',
    'LineE__05' : '$E_\\mathrm{Cyc2}$',
    'Sigma__6' : '$\sigma_\\mathrm{Cyc2}$',
    'Sigma__06' : '$\sigma_\\mathrm{Cyc2}$',
    'Strength__7' : '$\\tau_\\mathrm{Cyc2}$',
    'Strength__07' : '$\\tau_\\mathrm{Cyc2}$',
    
    'LineE__8' : '$E_\\mathrm{Cyc3}$',
    'LineE__08' : '$E_\\mathrm{Cyc3}$',
    'Sigma__9' : '$\sigma_\\mathrm{Cyc3}$',
    'Sigma__09' : '$\sigma_\\mathrm{Cyc3}$',
    'Strength__10' : '$\\tau_\\mathrm{Cyc3}$',
    
    'cutoffE__11': '$E_\\mathrm{C}$',
    'foldE__12': '$E_\\mathrm{F}$',
    'kT__13': '$kT_\\mathrm{BB}$',
    'norm__14' : '$r^2_\\mathrm{BB}$',
        
     'norm__21': 'F [$10^{-12}$cgs]', #$_\mathrm{2-10 keV}$
    'norm__42': 'Flux (3-20 keV)',
    'PhoIndex__18': '$\\Gamma$',
})

# %% [markdown]
# ## Dump the latex table of parameters (you will need to make adjustements for the paper)

# %%
fit_res
# Out:
# {'rate': [63.24017059584069, 63.18577773099951, 63.294563460681864],
#  'cstat': [496.86485592032784, 419],
#  'plot_filename': 'GW-mod_pcfabs_2gauss_2gabs-euf_plot.png',
#  'nH__01': [2.286045868872724, 2.282813659384136, 2.2892121080127326],
#  'nH__02': [38.471527694564635, 38.45382681484922, 38.49107369525286],
#  'CvrFract__03': [0.5564127915977765, 0.5561664052274375, 0.5566852477178656],
#  'LineE__04': [29.065176034272632, 29.055070900848342, 29.075395192733374],
#  'Sigma__05': [4.53339281881362, 4.529899246847993, 4.536625824253183],
#  'Strength__06': [4.726065069234626, 4.725198604781467, 4.726855678277358],
#  'LineE__07': [14.50077850136836, 14.484777292617133, 14.516125507708237],
#  'Sigma__08': [0.6776851722023098, 0.6761123167724544, 0.6792157229911244],
#  'Strength__09': [0.13346350314224203,
#   0.1331684765606284,
#   0.13377241808735438],
#  'cutoffE__10': [14.424122288160955, 14.417614538089264, 14.430009523410538],
#  'foldE__11': [9.188597978245259, 9.175004572044593, 9.201218135712834],
#  'LineE__12': [6.356084140695079, 6.352267324365397, 6.359636183010759],
#  'Sigma__13': [0.1869996273899218, 0.1863042481918611, 0.18768202555658547],
#  'norm__14': [0.00312464966088258,
#   0.0029228620263403522,
#   0.0033239163478240175],
#  'norm__20': [0.0005882283278860157,
#   0.0005603004803675267,
#   0.0006157604997424913],
#  'PhoIndex__21': [1.3113475914343669, 1.3099647987936058, 1.3128792821064716],
#  'norm__24': [13735.814296590639, 13735.452280342135, 13736.17472924021],
#  'norm__48': [13647.658058886414, 13646.382256220713, 13649.055117052467]}

# %%
latex_table = pysas.dump_latex_table({'aal': fit_res}, latex_label_dict=latex_label_dict, 
                                        to_skip=['plot_filename','norm__18', 'norm__20', 'times', 'rate'])
print(latex_table)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 latex_table = pysas.dump_latex_table({'aal': fit_res}, latex_label_dict=latex_label_dict,
#       2                                         to_skip=['plot_filename','norm__18', 'norm__20', 'times', 'rate'])
#       3 print(latex_table)
#
# File ~/src/pyxmmsas/pyxmmsas/__init__.py:1215, in dump_latex_table(fit_by_bin, latex_label_dict, to_skip, flux_norm, get_unit)
#    1212     continue
#    1214 ff = np.array(fit_by_bin[kk][par])
# -> 1215 par_name = latex_label_dict[par]
#    1217 unit, ff, par_name = get_unit(par, kk, ff, par_name)
#    1219 if par == 'cstat':
#
# KeyError: 'CvrFract__03'

# %% [markdown]
# ## Plot the chain and the corner plot

# %%
#reload(pysas)
# %matplotlib notebook
import matplotlib.pyplot as plt
from astropy.table import Table
import corner
import xspec
from glob import glob
from matplotlib import rc
#fit_by_bin = {}

plot_chains=False
plot_corners=False

#Find the proper file
chains=sorted(glob('obs_spec/GW-*3gabs-chain.fits'))
print(chains)
#chains=sorted(glob('GW-pcfabs-chain.fits'))
rc('text', usetex=False)

for i,chain_name in enumerate(chains):

    if i > 5:
        continue
    
    print(chain_name)
    
    table_chain=Table.read(chain_name)
    chain_df=table_chain.to_pandas()
    
    if plot_chains:
        for kk in table_chain.keys():
            if kk != 'FIT_STATISTIC':
                continue
            ff=plt.figure()
            plt.plot(table_chain[kk], 'o')
            ax=ff.gca()
            ax.set_ylabel(kk)
    
    
    chain_par_names=table_chain.keys()
    
    to_drop=['FIT_STATISTIC']
    
    for kk in chain_par_names:
        if 'factor' in kk:
            to_drop.append(kk)
    
    for kk in to_drop:
        chain_df.drop(kk, 1,  inplace=True)
    
    labels=[latex_label_dict[kk] for kk in list(chain_df.columns) ]
    
    rc('text', usetex=False)
    if plot_corners:
        corner_plot=corner.corner(chain_df, bins=20, labels=labels, quantiles=[0.16,0.84],
                                  plot_datapoints=False)
        corner_plot.savefig(chain_name.replace('.fits','')+'_corner_%02d.pdf'%(i+1))
    rc('text', usetex=False)
    
    
    quantiles=chain_df.quantile([0.16,0.5,0.84],axis=0)
    print(quantiles)
    if i>3:
        break

# %% [markdown]
# ## Here we test another model...
